# %%
import os

import numpy as np
import pandas as pd
import lightgbm as lgb

from sklearn.externals import joblib
# Out:
# C:\Users\jun\anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
# 目的変数の重要度
model_path = os.path.join('../model/model', 'lgbm1-train-all-all.model')
model = joblib.load(model_path)
lgb.plot_importance(model, height=0.5, figsize=(4,32))
